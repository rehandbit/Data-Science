# %%
pwd
# Out:
# '/home/rehanfaraz/Documents/26-MAY-25-CDS-BUN-021-WDA1430-MAR/mla'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams['figure.figsize'] = (20, 8)

# %% [markdown]
# #### Display all row

# %%
pd.reset_option('display.max_rows',None)

# %%
sns.load_dataset('iris')
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
pd.set_option('display.max_rows', None)

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
df['sepal_length']
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: sepal_length, Length: 150, dtype: float64

# %%
sns.lineplot(data =df, x='sepal_length',y='sepal_width', hue='species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(x = 'sepal_length', y = 'sepal_width', data = df , errorbar=None)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(x = 'sepal_length', y = 'petal_length', data = df, errorbar= None)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.lineplot(x = 'sepal_length', y = 'petal_width', data = df, errorbar = None)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_width'>

# %%
sns.lineplot(x = 'petal_length', y = 'sepal_width', data = df, errorbar = None)
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_width'>

# %%
sns.lineplot(x = 'petal_length', y = 'sepal_length', data = df, errorbar = None)
# Out:
# <Axes: xlabel='petal_length', ylabel='sepal_length'>

# %%
sns.lineplot(data = df, errorbar = None)
# Out:
# <Axes: >

# %%
sns.lineplot(x = 'petal_width', y = 'petal_length',data = df, hue = 'species')
# Out:
# <Axes: xlabel='petal_width', ylabel='petal_length'>

# %%
sns.lineplot(x = 'sepal_length', y = 'species',hue='species', data = df, errorbar = None)
# Out:
# <Axes: xlabel='sepal_length', ylabel='species'>

# %%
sns.lineplot(x = 'sepal_width', y = 'species',hue='species', data = df, errorbar = None)
# Out:
# <Axes: xlabel='sepal_width', ylabel='species'>

# %%
sns.lineplot(x = 'petal_length', y = 'species',hue='species', data = df, errorbar = None)
# Out:
# <Axes: xlabel='petal_length', ylabel='species'>

# %%
sns.lineplot(x = 'petal_width', y = 'species',hue='species', data = df)
# Out:
# <Axes: xlabel='petal_width', ylabel='species'>

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.countplot(data = df, x = 'species', hue='sepal_length')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.countplot(data = df, x = 'species', hue='species')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.countplot(data = df, x = 'species', hue='sepal_width')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.countplot(data = df, x = 'species', hue='petal_length')
# Out:
# <Axes: xlabel='species', ylabel='count'>

# %%
sns.scatterplot(data = df, x = 'sepal_length', y= 'sepal_width',hue = 'species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(data =df[df['species']=='setosa'], x='sepal_length',y='sepal_width')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(data =df[df['species']=='versicolor'], x='sepal_length',y='sepal_width', color= 'green')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.lineplot(data =df[df['species']=='virginica'], x='sepal_length',y='sepal_width', color= 'blue')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(data = df[df["species"] == 'versicolor'] , x = 'sepal_length', y= 'sepal_width', color='orange')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(data = df[df["species"] == 'virginica'] , x = 'sepal_length', y= 'sepal_width', color='green')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.countplot(data = df, x = 'sepal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='count'>

# %%
sns.countplot(data = df, x = 'sepal_length', hue = 'species')
# Out:
# <Axes: xlabel='sepal_length', ylabel='count'>

# %%
sns.jointplot(x='sepal_length', y = 'sepal_width', data=df)
plt.show()

# %%
sns.jointplot(x='sepal_length', y = 'sepal_width', data=df, hue = 'species')

# %%
sns.FacetGrid(df, hue='species').map(plt.scatter, 'sepal_length','sepal_width').add_legend()

# %%
sns.jointplot(x='petal_length', y = 'petal_width', data=df, hue = 'species')

# %%
sns.boxplot(x='species',y= 'petal_length', data=df, hue = 'species')
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.boxplot(x='species',y= 'petal_length', data=df, hue = 'species')
sns.stripplot(x='species',y= 'petal_length', data=df, hue = 'species', jitter=True)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
# violin plot

sns.violinplot(
    x= 'species', y = 'petal_length', data=df, hue = 'species'
)
# Out:
# <Axes: xlabel='species', ylabel='petal_length'>

# %%
sns.violinplot(x='species',y='sepal_length',data=df, hue='species')
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
sns.FacetGrid(data=df, hue='species', height=8).map(sns.kdeplot, 'petal_length')

# %%
sns.pairplot(data=df, hue= 'species', height=5)

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue='species')

# %%
sns.pairplot(df, diag_kind='hist', hue = 'species')
# diag_kind : {auto, hist, kde, none}

# %%
sns.scatterplot(df)
# Out:
# <Axes: >

# %%
sns.scatterplot(df[df.species == 'setosa'], x='sepal_length', y= 'sepal_width', color = 'orange', label='Setosa')
sns.scatterplot(df[df.species == 'versicolor'], x='sepal_length', y= 'sepal_width', color = 'blue', label='versicolor')
sns.scatterplot(df[df.species == 'virginica'], x='sepal_length', y= 'sepal_width', color = 'green', label='virginica')
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
df.hist(edgecolor = 'black')
fig = plt.gcf()
fig.set_size_inches(12,9)

# %% [markdown]
# /*Now the given problem is a classification problem.. Thus we will be using the classification algorithms to build a model.
#
# Classification: Samples belong to two or more classes and we want to learn from already labeled data how to predict the class of unlabeled data
#
# Regression: If the desired output consists of one or more continuous variables, then the task is called regression. An example of a regression problem would be the prediction of the length of a salmon as a function of its age and weight.
#
# Before we start, we need to clear some ML notations.
#
# attributes-->An attribute is a property of an instance that may be used to determine its classification. In the following dataset, the attributes are the petal and sepal length and width. It is also known as Features.
# Target variable, in the machine learning context is the variable that is or should be the output. Here the target variables are the 3 flower species.*/

# %%
df.to_csv('iris_download', index=False)
