# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
import pandas as pd

df=pd.read_csv('1_Churn_Modelling.csv')

df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.drop(["RowNumber","CustomerId","Surname"],axis=1,inplace=True)

# %%
df
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
df.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.describe()
# Out:
#         CreditScore           Age        Tenure        Balance  NumOfProducts  \
# count  10000.000000  10000.000000  10000.000000   10000.000000   10000.000000
# mean     650.528800     38.921800      5.012800   76485.889288       1.530200
# std       96.653299     10.487806      2.892174   62397.405202       0.581654
# min      350.000000     18.000000      0.000000       0.000000       1.000000
# 25%      584.000000     32.000000      3.000000       0.000000       1.000000
# 50%      652.000000     37.000000      5.000000   97198.540000       1.000000
# 75%      718.000000     44.000000      7.000000  127644.240000       2.000000
# max      850.000000     92.000000     10.000000  250898.090000       4.000000
#
#          HasCrCard  IsActiveMember  EstimatedSalary        Exited
# count  10000.00000    10000.000000     10000.000000  10000.000000
# mean       0.70550        0.515100    100090.239881      0.203700
# std        0.45584        0.499797     57510.492818      0.402769
# ...

# %%
#Encoding

df['Geography'].value_counts()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: count, dtype: int64

# %%
df.groupby('Geography').mean(['Exited'])['Exited']
# Out:
# Geography
# France     0.161548
# Germany    0.324432
# Spain      0.166734
# Name: Exited, dtype: float64

# %%
df.groupby('Geography').sum(['Exited'])['Exited']
# Out:
# Geography
# France     810
# Germany    814
# Spain      413
# Name: Exited, dtype: int64

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
#one-hot encoding

geography_onehot= pd.get_dummies(df['Geography'],drop_first=True).astype('int')
geography_onehot
# Out:
#       Germany  Spain
# 0           0      0
# 1           0      1
# 2           0      0
# 3           0      0
# 4           0      1
# ...       ...    ...
# 9995        0      0
# 9996        0      0
# 9997        0      0
# 9998        1      0
# 9999        0      0
#
# [10000 rows x 2 columns]

# %%
geography_onehot.head()
# Out:
#    Germany  Spain
# 0        0      0
# 1        0      1
# 2        0      0
# 3        0      0
# 4        0      1

# %% [markdown]
# pd.get_dummies(df.Gender)

# %%
gender_onehot=pd.get_dummies(df['Gender'],drop_first=True).astype('int')

# %%
# df.drop(['Geography','Gender'],axis=1,inplace=True)

df2 = pd.concat([df,geography_onehot,gender_onehot],axis=1)
df2
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
# ...

# %%
df2.head(50)
# Out:
#     CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0           619    France  Female   42       2       0.00              1
# 1           608     Spain  Female   41       1   83807.86              1
# 2           502    France  Female   42       8  159660.80              3
# 3           699    France  Female   39       1       0.00              2
# 4           850     Spain  Female   43       2  125510.82              1
# 5           645     Spain    Male   44       8  113755.78              2
# 6           822    France    Male   50       7       0.00              2
# 7           376   Germany  Female   29       4  115046.74              4
# 8           501    France    Male   44       4  142051.07              2
# 9           684    France    Male   27       2  134603.88              1
# 10          528    France    Male   31       6  102016.72              2
# 11          497     Spain    Male   24       3       0.00              2
# ...

# %%
df2.drop(['Gender','Geography'], axis= 1, inplace = True)

# %%
df2
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Germany  Spain  Male
# 0                  1        101348.88       1        0      0     0
# ...

# %%
#x, y split
X=df2.drop('Exited',axis=1)

y=df2.Exited

# %%
#train test split:

from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42)

# %%
X_test
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 6252          596   32       3   96709.07              2          0
# 4684          623   43       1       0.00              2          1
# 1731          601   44       4       0.00              2          1
# 4742          506   59       8  119152.10              2          1
# 4521          560   27       7  124995.98              1          1
# ...           ...  ...     ...        ...            ...        ...
# 4862          645   55       1  133676.65              1          0
# 7025          569   51       3       0.00              3          1
# 7647          768   25       0   78396.08              1          1
# 7161          690   36       6  110480.48              1          0
# 73            604   25       5  157780.84              2          1
#
#       IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 6252               0         41788.37        1      0     1
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
lg_model = LinearRegression()
lg_model
# Out:
# LinearRegression()

# %%
lg_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lg_ytrain = lg_model.predict(X_train)

# %%
lg_ytrain
# Out:
# array([0.32561906, 0.32830379, 0.1762776 , ..., 0.23621286, 0.29018324,
#        0.35612154])

# %%
from sklearn.tree import DecisionTreeClassifier

model1 = DecisionTreeClassifier()

model1
# Out:
# DecisionTreeClassifier()

# %%
model1.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_train_pred = model1.predict(X_train)
y_train_pred
# Out:
# array([1, 0, 0, ..., 1, 1, 0])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_train_pred, y_train)
# Out:
# 1.0

# %%
# training accuracy

y_train_pred = model1.predict(X_train)

# %%
y_train_pred
# Out:
# array([1, 0, 0, ..., 1, 1, 0])

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_train_pred,y_train)
# Out:
# 1.0

# %%
y_test_pred= model1.predict(X_test)

# %%
accuracy_score(y_test_pred, y_test)
# Out:
# 0.7952

# %% [markdown]
# #Tuning the hyper parameters

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
parameter_grid = {
    'max_depth': [5,10,15,None],
    'min_samples_split': [2,5,10,15],
    'min_samples_leaf':[10,15,20],
}

# %%
gridsearch = GridSearchCV(
    estimator=DecisionTreeClassifier(),
    param_grid = parameter_grid,
    scoring='f1',
    cv=5,
    verbose=1)

# %%
gridsearch.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'max_depth': [5, 10, 15, None],
#                          'min_samples_leaf': [10, 15, 20],
#                          'min_samples_split': [2, 5, 10, 15]},
#              scoring='f1', verbose=1)

# %%
gridsearch.best_params_
# Out:
# {'max_depth': 10, 'min_samples_leaf': 20, 'min_samples_split': 5}

# %%
model2=DecisionTreeClassifier(max_depth=5,min_samples_leaf=10,min_samples_split=2)

# %%
model2.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, min_samples_leaf=10)

# %%
y_train_pred=model2.predict(X_train)
y_test_pred=model2.predict(X_test)

# %%
accuracy_score(y_train_pred,y_train)
# Out:
# 0.8566666666666667

# %%
accuracy_score(y_test_pred,y_test)
# Out:
# 0.8596

# %%
df['Exited'].value_counts()
# Out:
# Exited
# 0    7963
# 1    2037
# Name: count, dtype: int64

# %%
from sklearn.metrics import classification_report
print(
classification_report(y_test_pred,y_test)
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.87      0.92      2250
#            1       0.40      0.79      0.53       250
#
#     accuracy                           0.86      2500
#    macro avg       0.69      0.83      0.72      2500
# weighted avg       0.92      0.86      0.88      2500

# %%
model3= gridsearch.best_estimator_

# %%
model3.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, min_samples_leaf=20, min_samples_split=5)

# %%
y_pred_test= model3.predict(X_test)

# %%
y_pred_test

# %%
from sklearn.metrics import classification_report
print(
classification_report(y_pred_test,y_test)
)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.88      0.91      2176
#            1       0.46      0.71      0.56       324
#
#     accuracy                           0.85      2500
#    macro avg       0.71      0.79      0.74      2500
# weighted avg       0.89      0.85      0.87      2500

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model_random_forest=RandomForestClassifier()
